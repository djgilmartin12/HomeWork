# %%
# Load Pandas into Python
import pandas as pd
from matplotlib import pyplot as plt
 
# %matplotlib inline

# %%
ufo.Year.value_counts().sort_index().head(10)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-05ff9ef1fe23> in <module>()
# ----> 1 ufo.Year.value_counts().sort_index().head(10)
#
# NameError: name 'ufo' is not defined

# %%
ufo = pd.read_csv('ufo.csv')
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year

# %%
ufo.Year.value_counts().sort_index().head(10)
# Out:
# 1930    2
# 1931    2
# 1933    1
# 1934    1
# 1935    1
# 1936    2
# 1937    2
# 1939    3
# 1941    2
# 1942    3
# Name: Year, dtype: int64

# %%
type(ufo.Year.value_counts())
# Out:
# pandas.core.series.Series

# %%
ufo.Year.value_counts().sort_index().plot();

# %%
drinks.continent.value_counts().plot(kind='bar');
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-9-4afef9e540ac> in <module>()
# ----> 1 drinks.continent.value_counts().plot(kind='bar');
#
# NameError: name 'drinks' is not defined

# %%
df.plot();
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-10-10028feb39d8> in <module>()
# ----> 1 df.plot();
#
# NameError: name 'df' is not defined

# %%
housing_csv = 'housing.csv'
housing = pd.read_csv(housing_csv)

# %%
with plt.style.context('seaborn-paper', after_reset=True):
    housing[['ZN', 'INDUS']].plot(style={'INDUS': '--'}, color=['green', 'blue'])

# %%
drinks.sum('continent')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-19-b00add95c5c3> in <module>()
# ----> 1 drinks.sum('continent')
#
# NameError: name 'drinks' is not defined

# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline 

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=['col1', 'col2', 'col3', 'col4'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

# %%
ax = df[['col1', 'col2']].plot(kind='bar');
ax.set_title('Some Kinda Plot Thingy', fontsize=21, y=1.01);
ax.legend(loc=0);
